# %% [markdown]
# # What to RAG/vectorize (and why)
#
# We retrieval evidence that helps the LLM map TDs → Node-RED nodes and patterns.
#
# **High-value corpora to embed/index:**
#
# * Our corpus of device *Thing Descriptions (TDs)*, because they are the canonical spec of needed transports and affordances. (Top priority.)
# * Example Node-RED flows that we already accept as “correct” (gold standard). These teach layout and wiring style.
# * Node-RED documentation pages describing node types and their configuration (socket, mqtt, http-in, websocket nodes).
# * node-specific docs for third-party nodes we use (e.g., `node-red-contrib-websocket`, `node-red-node-wot`, `node-red-contrib-xxxx`).
# * Protocol docs with examples (WebSocket message formats, MQTT topic conventions) if we need message parsing examples or JSON schemas.
# * Domain information via web search
#
# **Less useful/low priority:**
# * Entire books on Node-RED — useful for background but too noisy unless we want style guidance.
#
# **How to use RAG:**
# * Retrieve the most similar TD + best-matching example flow, and pass those into the LLM as context when generating the subflow. This reduces hallucination of transports or incorrect wiring.

# %%
urls = [
    "https://nodered.org/docs/tutorials/first-flow",
    "https://nodered.org/docs/tutorials/second-flow",
    "https://cookbook.nodered.org/http/create-an-http-endpoint",
    "https://cookbook.nodered.org/http/handle-query-parameters",
    "https://cookbook.nodered.org/http/handle-url-parameters",
    "https://cookbook.nodered.org/http/access-http-request-headers",
    "https://cookbook.nodered.org/http/include-data-from-another-flow",
    "https://cookbook.nodered.org/http/serve-json-content",
    "https://cookbook.nodered.org/http/simple-get-request",
    "https://cookbook.nodered.org/http/set-request-url",
    "https://cookbook.nodered.org/http/set-request-url-template",
    "https://cookbook.nodered.org/http/set-query-string",
    "https://cookbook.nodered.org/http/parse-json-response",
    "https://cookbook.nodered.org/http/get-binary-response",
    "https://cookbook.nodered.org/http/set-request-header",
    "https://cookbook.nodered.org/mqtt/connect-to-broker",
    "https://cookbook.nodered.org/mqtt/publish-to-topic",
    "https://cookbook.nodered.org/mqtt/set-publish-topic",
    "https://cookbook.nodered.org/mqtt/publish-retained-message",
    "https://cookbook.nodered.org/mqtt/subscribe-to-topic",
    "https://cookbook.nodered.org/mqtt/receive-json",
    "https://nodered.org/docs/developing-flows/flow-structure",
    "https://nodered.org/docs/developing-flows/message-design",
    "https://nodered.org/docs/api/admin/types",
    "https://www.w3.org/TR/wot-architecture/",
    "https://www.w3.org/TR/wot-thing-description11/",
    "https://github.com/eclipse-thingweb/node-red/blob/main/node-red-node-wot/examples/server-side-flows.json",
    "https://github.com/eclipse-thingweb/node-red/blob/main/node-red-node-wot/examples/client-side-flows.json",
    "https://github.com/eclipse-thingweb/node-red/tree/main/node-red-node-wot",
]

# %%
# %pip install langchain-openai langchain-core langchain langchain-text-splitters langchain-community bs4
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: langchain-openai in c:\users\ashfamt\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (1.0.3)
# Requirement already satisfied: langchain-core in c:\users\ashfamt\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (1.0.5)
# Collecting langchain
#   Downloading langchain-1.0.8-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: langchain-text-splitters in c:\users\ashfamt\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (1.0.0)
# Requirement already satisfied: langchain-community in c:\users\ashfamt\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (0.4.1)
# Collecting bs4
#   Downloading bs4-0.0.2-py2.py3-none-any.whl.metadata (411 bytes)
# Requirement already satisfied: openai<3.0.0,>=1.109.1 in c:\users\ashfamt\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from langchain-openai) (2.8.0)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in c:\users\ashfamt\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from langchain-openai) (0.12.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\ashfamt\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from langchain-core) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\ashfamt\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from langchain-core) (0.4.43)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\ashfamt\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from langchain-core) (25.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\ashfamt\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from langchain-core) (2.12.4)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\ashfamt\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from langchain-core) (6.0.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\ashfamt\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from langchain-core) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\ashfamt\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from langchain-core) (4.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\ashfamt\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\ashfamt\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\ashfamt\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (3.11.4)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\ashfamt\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\ashfamt\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\ashfamt\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (0.25.0)
# Requirement already satisfied: anyio in c:\users\ashfamt\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core) (4.9.0)
# Requirement already satisfied: certifi in c:\users\ashfamt\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core) (2025.7.14)
# Requirement already satisfied: httpcore==1.* in c:\users\ashfamt\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core) (1.0.9)
# Requirement already satisfied: idna in c:\users\ashfamt\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core) (3.10)
# Requirement already satisfied: h11>=0.16 in c:\users\ashfamt\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core) (0.16.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\ashfamt\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in c:\users\ashfamt\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (0.12.0)
# Requirement already satisfied: sniffio in c:\users\ashfamt\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\ashfamt\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (4.67.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\ashfamt\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\ashfamt\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\ashfamt\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core) (0.4.2)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\ashfamt\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai) (2025.11.3)
# Collecting langchain-core
#   Downloading langchain_core-1.0.6-py3-none-any.whl.metadata (3.6 kB)
# Collecting langgraph<1.1.0,>=1.0.2 (from langchain)
#   Downloading langgraph-1.0.3-py3-none-any.whl.metadata (7.8 kB)
# Collecting langgraph-checkpoint<4.0.0,>=2.1.0 (from langgraph<1.1.0,>=1.0.2->langchain)
#   Downloading langgraph_checkpoint-3.0.1-py3-none-any.whl.metadata (4.7 kB)
# Collecting langgraph-prebuilt<1.1.0,>=1.0.2 (from langgraph<1.1.0,>=1.0.2->langchain)
#   Downloading langgraph_prebuilt-1.0.4-py3-none-any.whl.metadata (5.2 kB)
# Collecting langgraph-sdk<0.3.0,>=0.2.2 (from langgraph<1.1.0,>=1.0.2->langchain)
#   Downloading langgraph_sdk-0.2.9-py3-none-any.whl.metadata (1.5 kB)
# Collecting xxhash>=3.5.0 (from langgraph<1.1.0,>=1.0.2->langchain)
#   Downloading xxhash-3.6.0-cp313-cp313-win_amd64.whl.metadata (13 kB)
# Collecting ormsgpack>=1.12.0 (from langgraph-checkpoint<4.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.2->langchain)
#   Downloading ormsgpack-1.12.0-cp313-cp313-win_amd64.whl.metadata (1.2 kB)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in c:\users\ashfamt\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from langchain-community) (1.0.0)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in c:\users\ashfamt\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from langchain-community) (2.0.44)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\ashfamt\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from langchain-community) (3.13.2)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in c:\users\ashfamt\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in c:\users\ashfamt\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from langchain-community) (2.12.0)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\users\ashfamt\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: numpy>=2.1.0 in c:\users\ashfamt\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from langchain-community) (2.3.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\ashfamt\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\ashfamt\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\ashfamt\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\ashfamt\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\ashfamt\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\ashfamt\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\ashfamt\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.22.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\ashfamt\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\ashfamt\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (0.9.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\ashfamt\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.2.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\ashfamt\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ashfamt\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core) (2.5.0)
# Requirement already satisfied: greenlet>=1 in c:\users\ashfamt\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain-community) (3.2.4)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\ashfamt\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community) (1.1.0)
# Collecting beautifulsoup4 (from bs4)
#   Downloading beautifulsoup4-4.14.2-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: colorama in c:\users\ashfamt\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from tqdm>4->openai<3.0.0,>=1.109.1->langchain-openai) (0.4.6)
# Collecting soupsieve>1.2 (from beautifulsoup4->bs4)
#   Downloading soupsieve-2.8-py3-none-any.whl.metadata (4.6 kB)
# Downloading langchain-1.0.8-py3-none-any.whl (93 kB)
# Downloading langchain_core-1.0.6-py3-none-any.whl (471 kB)
# Downloading langgraph-1.0.3-py3-none-any.whl (156 kB)
# Downloading langgraph_checkpoint-3.0.1-py3-none-any.whl (46 kB)
# Downloading langgraph_prebuilt-1.0.4-py3-none-any.whl (34 kB)
# Downloading langgraph_sdk-0.2.9-py3-none-any.whl (56 kB)
# Downloading bs4-0.0.2-py2.py3-none-any.whl (1.2 kB)
# Downloading ormsgpack-1.12.0-cp313-cp313-win_amd64.whl (112 kB)
# Downloading xxhash-3.6.0-cp313-cp313-win_amd64.whl (31 kB)
# Downloading beautifulsoup4-4.14.2-py3-none-any.whl (106 kB)
# Downloading soupsieve-2.8-py3-none-any.whl (36 kB)
# Installing collected packages: xxhash, soupsieve, ormsgpack, beautifulsoup4, langgraph-sdk, bs4, langchain-core, langgraph-checkpoint, langgraph-prebuilt, langgraph, langchain
#
#    ------- --------------------------------  2/11 [ormsgpack]
#    ---------- -----------------------------  3/11 [beautifulsoup4]
#    -------------- -------------------------  4/11 [langgraph-sdk]
#   Attempting uninstall: langchain-core
#    -------------- -------------------------  4/11 [langgraph-sdk]
#     Found existing installation: langchain-core 1.0.5
#    -------------- -------------------------  4/11 [langgraph-sdk]
#    --------------------- ------------------  6/11 [langchain-core]
#     Uninstalling langchain-core-1.0.5:
#    --------------------- ------------------  6/11 [langchain-core]
#       Successfully uninstalled langchain-core-1.0.5
#    --------------------- ------------------  6/11 [langchain-core]
#    --------------------- ------------------  6/11 [langchain-core]
#    --------------------- ------------------  6/11 [langchain-core]
#    --------------------- ------------------  6/11 [langchain-core]
#    --------------------- ------------------  6/11 [langchain-core]
#    --------------------- ------------------  6/11 [langchain-core]
#    --------------------- ------------------  6/11 [langchain-core]
#    --------------------- ------------------  6/11 [langchain-core]
#    --------------------- ------------------  6/11 [langchain-core]
#    --------------------- ------------------  6/11 [langchain-core]
#    ------------------------- --------------  7/11 [langgraph-checkpoint]
#    -------------------------------- -------  9/11 [langgraph]
#    -------------------------------- -------  9/11 [langgraph]
#    -------------------------------- -------  9/11 [langgraph]
#    ------------------------------------ --- 10/11 [langchain]
#    ------------------------------------ --- 10/11 [langchain]
#    ---------------------------------------- 11/11 [langchain]
#
# Successfully installed beautifulsoup4-4.14.2 bs4-0.0.2 langchain-1.0.8 langchain-core-1.0.6 langgraph-1.0.3 langgraph-checkpoint-3.0.1 langgraph-prebuilt-1.0.4 langgraph-sdk-0.2.9 ormsgpack-1.12.0 soupsieve-2.8 xxhash-3.6.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: C:\Users\ashfamt\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import getpass
import os

os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY") or getpass.getpass("Enter OpenAI API Key: ")

# %%
# Optional
os.environ["LANGSMITH_API_KEY"] = os.getenv("LANGSMITH_API_KEY") or getpass.getpass("Enter LangSmith API Key")
os.environ["LANGCHAIN_TRACING_V2"] = "true"
os.environ["LANGCHAIN_ENDPOINT"] = "https://api.smith.langchain.com"
os.environ["LANGCHAIN_PROJECT"] = "LLMSoSComp"

# %% [markdown]
# # Indexing

# %% [markdown]
# ## Load
#
# Load ALL pages at once with WebBaseLoader

# %%
from langchain_community.document_loaders import WebBaseLoader

loader = WebBaseLoader(web_paths=urls)
docs = loader.load()

print(len(docs), "documents loaded.")
assert len(docs) == len(urls)

print(docs[0].metadata)
print(docs[0].page_content[:500])
# Out:
# 29 documents loaded.
# {'source': 'https://nodered.org/docs/tutorials/first-flow', 'title': 'Creating your first flow : Node-RED', 'language': 'en'}
#
#
#
#
#
#
# Creating your first flow : Node-RED
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Node-RED
#
# home
# about
# blog
# documentation
# forum
# flows
# github
#
#
#
#
#
#
#
# docs
#
#          • tutorials
#         • first flow
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Creating your first flow
# Overview
# This tutorial introduces the Node-RED editor and creates a flow that demonstrates
# the Inject, Debug and Function nodes.
# 1. Access the editor
# With Node-RED running, open the editor in a web browser.
# If you are using a browser on the same computer that is

# %%
total_chars = sum(len(doc.page_content) for doc in docs)
print(f"Total Characters: {total_chars}")
# Out:
# Total Characters: 653079

# %% [markdown]
# ## Split

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=5000,
    chunk_overlap=500,
    add_start_index=True,  # Attaches the starting character index of each chunk in the original text as metadata.
)

all_splits = text_splitter.split_documents(docs)

print(f"splitted docs into {len(all_splits)} chunks")
# Out:
# splitted docs into 164 chunks

# %%
all_splits[5]
# Out:
# Document(metadata={'source': 'https://cookbook.nodered.org/http/handle-url-parameters', 'title': 'Handle url parameters in an HTTP endpoint : Node-RED', 'language': 'en', 'start_index': 5}, page_content='Handle url parameters in an HTTP endpoint : Node-RED\n\n\n\n\n\n\n\n\n\n\nNode-RED\n\nhome\nabout\nblog\ndocumentation\nforum\nflows\ngithub\n\n\n\n\n\n\n\n\ncookbook\n        \n        \n        • http• url parameters\n\n\n\n\n\nV\n\n\n\n\n\n\n\n        \xa0\n\n\n\n\nHandle url parameters in an HTTP endpoint\nProblem\nYou want to create a single HTTP endpoint that can handle requests where parts\nof the path are set per-request.\nFor example, a single endpoint that can handle requests to both:\nhttp://example.com/hello-param/Nick\nhttp://example.com/hello-param/Dave\n\nSolution\nUse named path parameters in your HTTP In node’s URL\nproperty and then access the specific value provided in a request using the\nmsg.req.params property of the message.\nFlow\n\n[{"id":"ce53954b.31ac68","type":"http response","z":"3045204d.cfbae","name":"","x":490,"y":280,"wires":[]},{"id":"288a7c0.fd77584","type":"template","z":"3045204d.cfbae","name":"page","field":"payload","fieldType":"msg","format":"handlebars","syntax":"mustache","template":"<html>\\n    <head></head>\\n    <body>\\n        <h1>Hello {{req.params.name}}!</h1>\\n    </body>\\n</html>","x":350,"y":280,"wires":[["ce53954b.31ac68"]]},{"id":"7665c67d.899a38","type":"http in","z":"3045204d.cfbae","name":"","url":"/hello-param/:name","method":"get","swaggerDoc":"","x":150,"y":280,"wires":[["288a7c0.fd77584"]]}]\n\nExample\n[~]$ curl http://localhost:1880/hello-param/Nick\n<html>\n    <head></head>\n    <body>\n        <h1>Hello Nick!</h1>\n    </body>\n</html>\n\nDiscussion\nNamed path parameters in the URL property can be used to identify parts of the\npath that can vary between requests.\nThe msg.req.params property is an object of key/value pairs for each path parameter.\nIn the above example, the node is configured with a URL of /hello-params/:name,\nso a request to /hello-param/Nick results in the msg.req.params property containing:\n{\n    "name": "Nick"\n}\n\nGot feedback about this page?  Let us know!\n\n\n\n\n\n\n\nNode-RED: Low-code programming for event-driven applications.\n\n\n\nGitHub\nnpm\nDocumentation\nAPIs\n\n\n\n\nFlow Library\nAbout\nCode of Conduct\nCommunity\n\n\n\n\nBlog\nTwitter\nForum\nSlack\n\n\n\n\n\n\n\n\nCopyright OpenJS Foundation and Node-RED contributors. All rights reserved. The OpenJS Foundation has registered trademarks and uses trademarks.  For a list of trademarks of the OpenJS Foundation, please see our Trademark Policy and Trademark List.  Trademarks and logos not indicated on the list of OpenJS Foundation trademarks are trademarks™ or registered® trademarks of their respective holders. Use of them does not imply any affiliation with or endorsement by them.\nThe OpenJS Foundation | Terms of Use | Privacy Policy | OpenJS Foundation Bylaws | Trademark Policy | Trademark List | Cookie Policy')

# %%
all_splits[162]
# Out:
# Document(metadata={'source': 'https://github.com/eclipse-thingweb/node-red/tree/main/node-red-node-wot', 'title': 'node-red/node-red-node-wot at main · eclipse-thingweb/node-red · GitHub', 'description': 'Collection of Node-RED packages of Eclipse Thingweb - node-red/node-red-node-wot at main · eclipse-thingweb/node-red', 'language': 'en', 'start_index': 92}, page_content='node-red/node-red-node-wot at main · eclipse-thingweb/node-red · GitHub\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nSkip to content\n\n\n\n\n\n\n\n\n\n\n\n\n\nNavigation Menu\n\nToggle navigation\n\n\n\n\n \n\n\n\n\n\n\n\n\n\n\n\n\n\n            Sign in\n          \n\n\n \n\n\nAppearance settings\n\n\n\n\n\n\n\n\n\n\n\n        Platform\n        \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n          GitHub Copilot\n\n        \n\n        Write better code with AI\n      \n\n\n\n\n\n\n\n\n          GitHub Spark\n\n            \n              New\n            \n\n\n        Build and deploy intelligent apps\n      \n\n\n\n\n\n\n\n\n          GitHub Models\n\n            \n              New\n            \n\n\n        Manage and compare prompts\n      \n\n\n\n\n\n\n\n\n          GitHub Advanced Security\n\n        \n\n        Find and fix vulnerabilities\n      \n\n\n\n\n\n\n\n\n          Actions\n\n        \n\n        Automate any workflow\n      \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n          Codespaces\n\n        \n\n        Instant dev environments\n      \n\n\n\n\n\n\n\n\n          Issues\n\n        \n\n        Plan and track work\n      \n\n\n\n\n\n\n\n\n          Code Review\n\n        \n\n        Manage code changes\n      \n\n\n\n\n\n\n\n\n          Discussions\n\n        \n\n        Collaborate outside of code\n      \n\n\n\n\n\n\n\n\n          Code Search\n\n        \n\n        Find more, search less\n      \n\n\n\n\n\n\nExplore\n\n\n\n      Why GitHub\n\n    \n\n\n\n      Documentation\n\n    \n\n\n\n\n\n      GitHub Skills\n\n    \n\n\n\n\n\n      Blog\n\n    \n\n\n\n\n\n\nIntegrations\n\n\n\n      GitHub Marketplace\n\n    \n\n\n\n      MCP Registry\n\n    \n\n\n\n\n\n\n\n              View all features\n              \n\n\n \n\n\n\n\n        Solutions\n        \n\n\n\n\n\n\n\nBy company size\n\n\n\n      Enterprises\n\n    \n\n\n\n      Small and medium teams\n\n    \n\n\n\n      Startups\n\n    \n\n\n\n      Nonprofits\n\n    \n\n\n\n\n\n\nBy use case\n\n\n\n      App Modernization\n\n    \n\n\n\n      DevSecOps\n\n    \n\n\n\n      DevOps\n\n    \n\n\n\n      CI/CD\n\n    \n\n\n\n      View all use cases\n\n    \n\n\n\n\n\n\nBy industry\n\n\n\n      Healthcare\n\n    \n\n\n\n      Financial services\n\n    \n\n\n\n      Manufacturing\n\n    \n\n\n\n      Government\n\n    \n\n\n\n      View all industries\n\n    \n\n\n\n\n\n\n\n              View all solutions\n              \n\n\n \n\n\n\n\n        Resources\n        \n\n\n\n\n\n\n\nTopics\n\n\n\n      AI\n\n    \n\n\n\n      DevOps\n\n    \n\n\n\n      Security\n\n    \n\n\n\n      Software Development\n\n    \n\n\n\n      View all\n\n    \n\n\n\n\n\n\nExplore\n\n\n\n      Learning Pathways\n\n    \n\n\n\n\n\n      Events & Webinars\n\n    \n\n\n\n      Ebooks & Whitepapers\n\n    \n\n\n\n      Customer Stories\n\n    \n\n\n\n      Partners\n\n    \n\n\n\n      Executive Insights\n\n    \n\n\n\n\n\n\n\n\n\n        Open Source\n        \n\n\n\n\n\n\n\n\n\n\n\n\n          GitHub Sponsors\n\n        \n\n        Fund open source developers\n      \n\n\n\n\n\n\n\n\n\n          The ReadME Project\n\n        \n\n        GitHub community articles\n      \n\n\n\n\nRepositories\n\n\n\n      Topics\n\n    \n\n\n\n      Trending\n\n    \n\n\n\n      Collections\n\n    \n\n\n\n\n\n\n\n\n\n        Enterprise\n        \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n          Enterprise platform\n\n        \n\n        AI-powered developer platform\n      \n\n\n\n\nAvailable add-ons\n\n\n\n\n\n\n\n\n          GitHub Advanced Security\n\n        \n\n        Enterprise-grade security features\n    ...

# %% [markdown]
# ## Store

# %%
# select embedding model
from langchain_openai import OpenAIEmbeddings

embeddings = OpenAIEmbeddings(model="text-embedding-3-large")

# %%
from langchain_core.vectorstores import InMemoryVectorStore

vector_store = InMemoryVectorStore(embeddings)

# %%
document_ids = vector_store.add_documents(documents=all_splits)

# %%
print(document_ids[:3])
# Out:
# ['a2fbef91-ccfa-441f-ad6e-e32b35b15da2', 'fa55a88c-cc34-4cca-8e2a-2b215293d1aa', '99e306c6-3c77-4821-ad01-bb5cc3211284']

# %% [markdown]
# # Retrieval and Generation

# %%
import sys
import os

parent_dir = os.path.abspath("..")
sys.path.append(parent_dir)

import utils

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model(
    model="gpt-4.1",
    temperature=0.0
)

# %%
# Retrieve relevant docs from your vector store
retrieved_docs = vector_store.similarity_search(
    utils.smart_home_system_description, k=4
)

# Join text for prompt context
docs_content = "\n\n".join(
    f"[Source: {doc.metadata.get('source','unknown')}]\n{doc.page_content}"
    for doc in retrieved_docs
)

# %%
user_prompt = """
    Desired Workflow: \n {desired_workflow}
    List of Devices as WoT Thing Descriptions: \n {thing_directory}

    Use the following relevant docs to help generate the workflow: \n {context_docs}
    """

# %%
from langchain_core.prompts import (
    ChatPromptTemplate,
    SystemMessagePromptTemplate, 
    HumanMessagePromptTemplate
)

prompt_template = ChatPromptTemplate.from_messages([
    SystemMessagePromptTemplate.from_template(utils.system_prompt),
    HumanMessagePromptTemplate.from_template(user_prompt)
])

# %%
prompt_template.input_variables
# Out:
# ['context_docs', 'desired_workflow', 'thing_directory']

# %%
pipeline = (
    {
        "thing_directory": lambda x: x["thing_directory"],
        "desired_workflow": lambda x: x["desired_workflow"],
        "context_docs": lambda x: x["context_docs"]
    }
    | prompt_template
    | model
    | {"generated_workflow": lambda x: x.content}
)

# %%
response = pipeline.invoke({
    "thing_directory": utils.smart_home_td_full,
    "desired_workflow": utils.smart_home_system_description,
    "context_docs": docs_content
})

# %%
response
# Out:
# {'generated_workflow': '[\n  {\n    "id": "n1-wm-finished-event",\n    "type": "websocket in",\n    "z": "main-flow",\n    "name": "WashingMachine finishedCycle",\n    "server": "",\n    "client": "",\n    "path": "ws://localhost:1880/things/wm/finishedCycle",\n    "x": 120,\n    "y": 60,\n    "wires": [\n      [\n        "n2-leds-blink"\n      ]\n    ]\n  },\n  {\n    "id": "n2-leds-blink",\n    "type": "http request",\n    "z": "main-flow",\n    "name": "Blink LEDs",\n    "method": "POST",\n    "ret": "txt",\n    "url": "http://localhost:1880/things/leds/blink",\n    "headers": {},\n    "x": 350,\n    "y": 60,\n    "wires": [\n      []\n    ]\n  },\n  {\n    "id": "n3-motion-detected",\n    "type": "websocket in",\n    "z": "main-flow",\n    "name": "MotionSensor motionDetected",\n    "server": "",\n    "client": "",\n    "path": "ws://localhost:1880/things/motionsensor/motiondetected",\n    "x": 120,\n    "y": 140,\n    "wires": [\n      [\n        "n4-light-on"\n      ]\n    ]\n  },\n  {\n    "id": "n4-light-on",\n    "type": "http request",\n    "z": "main-flow",\n    "name": "MainRoomLight On",\n    "method": "POST",\n    "ret": "txt",\n    "url": "http://localhost:1880/things/mainroomlight/on",\n    "headers": {},\n    "x": 350,\n    "y": 140,\n    "wires": [\n      []\n    ]\n  },\n  {\n    "id": "n5-doorbell-bellrung",\n    "type": "http in",\n    "z": "main-flow",\n    "name": "DoorBell bellRung",\n    "url": "/doorbell/bellRung",\n    "method": "post",\n    "upload": false,\n    "swaggerDoc": "",\n    "x": 120,\n    "y": 220,\n    "wires": [\n      [\n        "n6-get-speaker-volume"\n      ]\n    ]\n  },\n  {\n    "id": "n6-get-speaker-volume",\n    "type": "http request",\n    "z": "main-flow",\n    "name": "Get Speaker Volume",\n    "method": "GET",\n    "ret": "obj",\n    "url": "http://localhost:1880/things/speaker/volume",\n    "headers": {},\n    "x": 350,\n    "y": 220,\n    "wires": [\n      [\n        "n7-set-speaker-low"\n      ]\n    ]\n  },\n  {\n    "id": "n7-set-speaker-low",\n    "type": "function",\n    "z": "main-flow",\n    "name": "Set Speaker Volume Low",\n    "func": "msg.payload = { percentage: 10 };\\nreturn msg;",\n    "outputs": 1,\n    "noerr": 0,\n    "x": 570,\n    "y": 220,\n    "wires": [\n      [\n        "n8-set-speaker-volume"\n      ]\n    ]\n  },\n  {\n    "id": "n8-set-speaker-volume",\n    "type": "http request",\n    "z": "main-flow",\n    "name": "Set Speaker Volume (Low)",\n    "method": "POST",\n    "ret": "txt",\n    "url": "http://localhost:1880/things/speaker/setVolume",\n    "headers": {\n      "Content-Type": "application/json"\n    },\n    "x": 800,\n    "y": 220,\n    "wires": [\n      [\n        "n9-assistant-say"\n      ]\n    ]\n  },\n  {\n    "id": "n9-assistant-say",\n    "type": "function",\n    "z": "main-flow",\n    "name": "Assistant Alert",\n    "func": "msg.payload = { phrase: \\"Someone is at the door. The doorbell was pressed.\\" };\\nreturn msg;",\n    "outputs": 1,\n    "noerr": 0,\n    "x": 1050,\n    "y": 220,\n    "wires": [\n      [\n        "n10-assistant-say-http"\n      ]\n    ]\n  },\n  {\n    "id": "n10-assistant-say-http",\n    "type": "http request",\n    "z": "main-flow",\n    "name": "SmartAssistant Say",\n    "method": "POST",\n    "ret": "txt",\n    "url": "http://localhost:1880/things/smartassistant/say",\n    "headers": {\n      "Content-Type": "application/json"\n    },\n    "x": 1300,\n    "y": 220,\n    "wires": [\n      [\n        "n11-restore-speaker-volume"\n      ]\n    ]\n  },\n  {\n    "id": "n11-restore-speaker-volume",\n    "type": "function",\n    "z": "main-flow",\n    "name": "Restore Speaker Volume",\n    "func": "// Use flow context to store original volume\\nvar origVol = flow.get(\\"origSpeakerVol\\");\\nif (typeof origVol !== \\"number\\") {\\n    origVol = 50; // fallback\\n}\\nmsg.payload = { percentage: origVol };\\nreturn msg;",\n    "outputs": 1,\n    "noerr": 0,\n    "x": 1550,\n    "y": 220,\n    "wires": [\n    ...

# %%
# formatting the response

import json

# Parse twice: first to extract string, second to get proper JSON
workflow_str = response['generated_workflow']
workflow = json.loads(workflow_str)

# Now `workflow` is a list of dicts — ready for Node-RED
print(json.dumps(workflow, indent=2))
# Out:
# [
#   {
#     "id": "n1-wm-finished-event",
#     "type": "websocket in",
#     "z": "main-flow",
#     "name": "WashingMachine finishedCycle",
#     "server": "",
#     "client": "",
#     "path": "ws://localhost:1880/things/wm/finishedCycle",
#     "x": 120,
#     "y": 60,
#     "wires": [
#       [
#         "n2-leds-blink"
#       ]
#     ]
#   },
#   {
#     "id": "n2-leds-blink",
#     "type": "http request",
#     "z": "main-flow",
#     "name": "Blink LEDs",
#     "method": "POST",
#     "ret": "txt",
#     "url": "http://localhost:1880/things/leds/blink",
#     "headers": {},
#     "x": 350,
#     "y": 60,
#     "wires": [
#       []
#     ]
#   },
#   {
#     "id": "n3-motion-detected",
#     "type": "websocket in",
#     "z": "main-flow",
#     "name": "MotionSensor motionDetected",
#     "server": "",
#     "client": "",
#     "path": "ws://localhost:1880/things/motionsensor/motiondetected",
#     "x": 120,
#     "y": 140,
#     "wires": [
#       [
#         "n4-light-on"
#       ]
#     ]
#   },
#   {
#     "id": "n4-light-on",
#     "type": "http request",
#     "z": "main-flow",
#     "name": "MainRoomLight On",
#     "method": "POST",
#     "ret": "txt",
#     "url": "http://localhost:1880/things/mainroomlight/on",
#     "headers": {},
#     "x": 350,
#     "y": 140,
#     "wires": [
#       []
#     ]
#   },
#   {
#     "id": "n5-doorbell-bellrung",
#     "type": "http in",
#     "z": "main-flow",
#     "name": "DoorBell bellRung",
#     "url": "/doorbell/bellRung",
#     "method": "post",
#     "upload": false,
#     "swaggerDoc": "",
#     "x": 120,
#     "y": 220,
#     "wires": [
#       [
#         "n6-get-speaker-volume"
#       ]
#     ]
#   },
#   {
#     "id": "n6-get-speaker-volume",
#     "type": "http request",
#     "z": "main-flow",
#     "name": "Get Speaker Volume",
#     "method": "GET",
#     "ret": "obj",
#     "url": "http://localhost:1880/things/speaker/volume",
#     "headers": {},
#     "x": 350,
#     "y": 220,
#     "wires": [
#       [
#         "n7-set-speaker-low"
#       ]
#     ]
#   },
#   {
#     "id": "n7-set-speaker-low",
#     "type": "function",
#     "z": "main-flow",
#     "name": "Set Speaker Volume Low",
#     "func": "msg.payload = { percentage: 10 };\nreturn msg;",
#     "outputs": 1,
#     "noerr": 0,
#     "x": 570,
#     "y": 220,
#     "wires": [
#       [
#         "n8-set-speaker-volume"
#       ]
#     ]
#   },
#   {
#     "id": "n8-set-speaker-volume",
#     "type": "http request",
#     "z": "main-flow",
#     "name": "Set Speaker Volume (Low)",
#     "method": "POST",
#     "ret": "txt",
#     "url": "http://localhost:1880/things/speaker/setVolume",
#     "headers": {
#       "Content-Type": "application/json"
#     },
#     "x": 800,
#     "y": 220,
#     "wires": [
#       [
#         "n9-assistant-say"
#       ]
#     ]
#   },
#   {
#     "id": "n9-assistant-say",
#     "type": "function",
#     "z": "main-flow",
#     "name": "Assistant Alert",
#     "func": "msg.payload = { phrase: \"Someone is at the door. The doorbell was pressed.\" };\nreturn msg;",
#     "outputs": 1,
#     "noerr": 0,
#     "x": 1050,
#     "y": 220,
#     "wires": [
#       [
#         "n10-assistant-say-http"
#       ]
#     ]
#   },
#   {
#     "id": "n10-assistant-say-http",
#     "type": "http request",
#     "z": "main-flow",
#     "name": "SmartAssistant Say",
#     "method": "POST",
#     "ret": "txt",
#     "url": "http://localhost:1880/things/smartassistant/say",
#     "headers": {
#       "Content-Type": "application/json"
#     },
#     "x": 1300,
#     "y": 220,
#     "wires": [
#       [
#         "n11-restore-speaker-volume"
#       ]
#     ]
#   },
#   {
#     "id": "n11-restore-speaker-volume",
#     "type": "function",
#     "z": "main-flow",
#     "name": "Restore Speaker Volume",
#     "func": "// Use flow context to store original volume\nvar origVol = flow.get(\"origSpeakerVol\");\nif (typeof origVol !== \"number\") {\n    origVol = 50; // fallback\n}\nmsg.payload = { percentage: origVol };\nreturn msg;",
#     "outputs": 1,
#     "noerr": 0,
#     "x": 1550,
#     "y": 220,
#     "wires": [
#       [
#         "n12-set-speaker-volume-restore"
#       ]
#     ]
#   },
#   {
#     "id": "n12-set-speaker-volume-restore",
#     "type": "http request",
#     "z": "main-flow",
#     "name": "Set Speaker Volume (Restore)",
#     "method": "POST",
#     "ret": "txt",
#     "url": "http://localhost:1880/things/speaker/setVolume",
#     "headers": {
#       "Content-Type": "application/json"
#     },
#     "x": 1800,
#     "y": 220,
#     "wires": [
#       []
#     ]
#   },
#   {
#     "id": "n13-alarm-ringing",
#     "type": "http in",
#     "z": "main-flow",
#     "name": "Alarm alarmRinging",
#     "url": "/alarm/ringing",
#     "method": "post",
#     "upload": false,
#     "swaggerDoc": "",
#     "x": 120,
#     "y": 300,
#     "wires": [
#       [
#         "n14-heater-on"
#       ]
#     ]
#   },
#   {
#     "id": "n14-heater-on",
#     "type": "function",
#     "z": "main-flow",
#     "name": "Heater 30C 20min",
#     "func": "msg.payload = { temperature: 30, timeHeating: 20 };\nreturn msg;",
#     "outputs": 1,
#     "noerr": 0,
#     "x": 350,
#     "y": 300,
#     "wires": [
#       [
#         "n15-heater-start"
#       ]
#     ]
#   },
#   {
#     "id": "n15-heater-start",
#     "type": "http request",
#     "z": "main-flow",
#     "name": "Start Heater",
#     "method": "POST",
#     "ret": "txt",
#     "url": "http://localhost:1880/things/heater/startHeater",
#     "headers": {
#       "Content-Type": "application/json"
#     },
#     "x": 570,
#     "y": 300,
#     "wires": [
#       []
#     ]
#   },
#   {
#     "id": "n16-save-speaker-volume",
#     "type": "function",
#     "z": "main-flow",
#     "name": "Save Speaker Volume",
#     "func": "flow.set(\"origSpeakerVol\", msg.payload.volume || msg.payload);\nreturn msg;",
#     "outputs": 1,
#     "noerr": 0,
#     "x": 570,
#     "y": 260,
#     "wires": [
#       [
#         "n7-set-speaker-low"
#       ]
#     ]
#   },
#   {
#     "id": "n5b-doorbell-bellrung-ws",
#     "type": "http request",
#     "z": "main-flow",
#     "name": "DoorBell bellRung (poll)",
#     "method": "GET",
#     "ret": "obj",
#     "url": "http://localhost:1880/doorbell/bellRung",
#     "headers": {},
#     "x": 120,
#     "y": 180,
#     "wires": [
#       [
#         "n6-get-speaker-volume"
#       ]
#     ]
#   }
# ]
