# %% [markdown]
# # Selective RAG
#
# - RAG allows selective retrieval. Instead of dumping all TDS, the retriever hands the LLM the X relevant TDs for the goal. This allows scaling and precision. Warburton et al. [^9] pasted everything; we constrain context. No new node modules needed.
# - Query relevant context for the workflow generation.

# %% [markdown]
# Pipeline:
#
# - TDs -> Index 'em
# - query -> get relevant TD

# %%
# %pip install langchain-openai langchain-core langchain-community
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import getpass
import os

os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY") or getpass.getpass("Enter OpenAI API Key: ")

# %%
from langchain_openai import ChatOpenAI

openai_model = "gpt-4.1"
# For normal accurate responses
llm = ChatOpenAI(temperature=0.0, model=openai_model)

# %% [markdown]
# # TD Indexing
